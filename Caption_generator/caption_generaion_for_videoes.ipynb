# %%
import os

path = r"D:\Datasets\vid_caption"

video_names = [filename for filename in os.listdir(path) if filename.endswith(".avi")]

print(video_names)
# Out:
# ['v_ApplyEyeMakeup_g01_c01.avi', 'v_ApplyLipstick_g05_c01.avi', 'v_Archery_g01_c01.avi', 'v_BabyCrawling_g03_c01.avi', 'v_BalanceBeam_g02_c02.avi', 'v_BandMarching_g01_c01.avi', 'v_BaseballPitch_g02_c01.avi', 'v_BasketballDunk_g01_c01.avi', 'v_Basketball_g05_c02.avi', 'v_BenchPress_g01_c01.avi', 'v_Biking_g06_c01.avi', 'v_Billiards_g01_c01.avi', 'v_BlowDryHair_g01_c01.avi', 'v_BlowingCandles_g03_c01.avi', 'v_BodyWeightSquats_g02_c01.avi', 'v_Bowling_g01_c01.avi', 'v_BoxingPunchingBag_g01_c01.avi', 'v_BoxingSpeedBag_g03_c01.avi', 'v_BreastStroke_g02_c01.avi', 'v_BrushingTeeth_g05_c01.avi', 'v_CleanAndJerk_g02_c01.avi', 'v_CliffDiving_g03_c01.avi', 'v_CricketBowling_g01_c01.avi', 'v_CricketShot_g02_c01.avi', 'v_CuttingInKitchen_g02_c01.avi', 'v_Diving_g01_c01.avi', 'v_Drumming_g01_c01.avi', 'v_Fencing_g02_c01.avi', 'v_FieldHockeyPenalty_g01_c01.avi', 'v_FloorGymnastics_g03_c01.avi', 'v_FrisbeeCatch_g03_c01.avi', 'v_FrontCrawl_g01_c01.avi', 'v_GolfSwing_g01_c01.avi', 'v_Haircut_g05_c01.
# ...

# %%
modified_names = [name[2:-12] for name in video_names]
for name in modified_names:
    print(name)
# Out:
# ApplyEyeMakeup
# ApplyLipstick
# Archery
# BabyCrawling
# BalanceBeam
# BandMarching
# BaseballPitch
# BasketballDunk
# Basketball
# BenchPress
# Biking
# Billiards
# BlowDryHair
# BlowingCandles
# BodyWeightSquats
# Bowling
# BoxingPunchingBag
# BoxingSpeedBag
# BreastStroke
# BrushingTeeth
# CleanAndJerk
# CliffDiving
# CricketBowling
# CricketShot
# CuttingInKitchen
# Diving
# Drumming
# Fencing
# FieldHockeyPenalty
# FloorGymnastics
# FrisbeeCatch
# FrontCrawl
# GolfSwing
# Haircut
# Hammering
# HammerThrow
# HandStandPushups
# HandstandWalking
# HeadMassage
# HighJump
# HorseRace
# HorseRiding
# HulaHoop
# IceDancing
# JavelinThrow
# JugglingBalls
# JumpingJack
# JumpRope
# Kayaking
# Knitting
# LongJump
# Lunges
# MilitaryParade
# Mixing
# MoppingFloor
# Nunchucks
# ParallelBars
# PizzaTossing
# PlayingCello
# PlayingDaf
# PlayingDhol
# PlayingFlute
# PlayingGuitar
# PlayingPiano
# PlayingSitar
# PlayingTabla
# PlayingViolin
# PoleVault
# PommelHorse
# PullUps
# Punch
# ...

# %%
caption=modified_names

# %%
caption
# Out:
# ['ApplyEyeMakeup',
#  'ApplyLipstick',
#  'Archery',
#  'BabyCrawling',
#  'BalanceBeam',
#  'BandMarching',
#  'BaseballPitch',
#  'BasketballDunk',
#  'Basketball',
#  'BenchPress',
#  'Biking',
#  'Billiards',
#  'BlowDryHair',
#  'BlowingCandles',
#  'BodyWeightSquats',
#  'Bowling',
#  'BoxingPunchingBag',
#  'BoxingSpeedBag',
#  'BreastStroke',
#  'BrushingTeeth',
#  'CleanAndJerk',
#  'CliffDiving',
#  'CricketBowling',
#  'CricketShot',
#  'CuttingInKitchen',
#  'Diving',
#  'Drumming',
#  'Fencing',
#  'FieldHockeyPenalty',
#  'FloorGymnastics',
#  'FrisbeeCatch',
#  'FrontCrawl',
#  'GolfSwing',
#  'Haircut',
#  'Hammering',
#  'HammerThrow',
#  'HandStandPushups',
#  'HandstandWalking',
#  'HeadMassage',
#  'HighJump',
#  'HorseRace',
#  'HorseRiding',
#  'HulaHoop',
#  'IceDancing',
#  'JavelinThrow',
#  'JugglingBalls',
#  'JumpingJack',
#  'JumpRope',
#  'Kayaking',
#  'Knitting',
#  'LongJump',
#  'Lunges',
#  'MilitaryParade',
#  'Mixing',
#  'MoppingFloor',
# ...

# %%
video_caption={}
for original_name, modified_name in zip(video_names, modified_names):
    video_caption[original_name] = modified_name

print(video_caption)
# Out:
# {'v_ApplyEyeMakeup_g01_c01.avi': 'ApplyEyeMakeup', 'v_ApplyLipstick_g05_c01.avi': 'ApplyLipstick', 'v_Archery_g01_c01.avi': 'Archery', 'v_BabyCrawling_g03_c01.avi': 'BabyCrawling', 'v_BalanceBeam_g02_c02.avi': 'BalanceBeam', 'v_BandMarching_g01_c01.avi': 'BandMarching', 'v_BaseballPitch_g02_c01.avi': 'BaseballPitch', 'v_BasketballDunk_g01_c01.avi': 'BasketballDunk', 'v_Basketball_g05_c02.avi': 'Basketball', 'v_BenchPress_g01_c01.avi': 'BenchPress', 'v_Biking_g06_c01.avi': 'Biking', 'v_Billiards_g01_c01.avi': 'Billiards', 'v_BlowDryHair_g01_c01.avi': 'BlowDryHair', 'v_BlowingCandles_g03_c01.avi': 'BlowingCandles', 'v_BodyWeightSquats_g02_c01.avi': 'BodyWeightSquats', 'v_Bowling_g01_c01.avi': 'Bowling', 'v_BoxingPunchingBag_g01_c01.avi': 'BoxingPunchingBag', 'v_BoxingSpeedBag_g03_c01.avi': 'BoxingSpeedBag', 'v_BreastStroke_g02_c01.avi': 'BreastStroke', 'v_BrushingTeeth_g05_c01.avi': 'BrushingTeeth', 'v_CleanAndJerk_g02_c01.avi': 'CleanAndJerk', 'v_CliffDiving_g03_c01.avi': 'CliffDiving
# ...

# %%
# Convert the dictionary to a list of tuples (video_name, caption)
data = [(video_name, caption) for video_name, caption in video_caption.items()]

# Create a DataFrame from the list of tuples
df = pd.DataFrame(data, columns=['VideoName', 'Caption'])

df
# Out:
#                            VideoName            Caption
# 0       v_ApplyEyeMakeup_g01_c01.avi     ApplyEyeMakeup
# 1        v_ApplyLipstick_g05_c01.avi      ApplyLipstick
# 2              v_Archery_g01_c01.avi            Archery
# 3         v_BabyCrawling_g03_c01.avi       BabyCrawling
# 4          v_BalanceBeam_g02_c02.avi        BalanceBeam
# ..                               ...                ...
# 97   v_VolleyballSpiking_g01_c01.avi  VolleyballSpiking
# 98      v_WalkingWithDog_g01_c02.avi     WalkingWithDog
# 99         v_WallPushups_g02_c01.avi        WallPushups
# 100     v_WritingOnBoard_g03_c01.avi     WritingOnBoard
# 101               v_YoYo_g02_c01.avi               YoYo
#
# [102 rows x 2 columns]
